# %%
import  random
class Environment():
    
    #Initial location and condation
    # 0 is Clean   1 is Dirty
    def __init__(self):
        self.locationcondition={'A':'1','B':'1'}
        #Randomize condition
        print("Random Environment: ")
        self.locationcondition['A']=random.randint(0,1)
        self.locationcondition['B']=random.randint(0,1)

# %%
class Sreflexagent(Environment):
    
    def __init__(self, Environment):
        self.Environment=Environment
        print(Environment.locationcondition)
        #0 is locatin A    1 is location B
        vacumlocation=random.randint(0,1)
        
        #if vacum in A
        if vacumlocation==0:
            print("Vacum is randomly placed at location A.")
            #and if location A is dirty 
            if Environment.locationcondition['A']==1:
                print("location A is dirty.")
                #suck the dirt and mark it clean
                Environment.locationcondition['A']=0
                print("location A has been clean.")
                print("moving to location B")
            else:
              print("location A was cleaned")
              print("moving to location B")
              
            #and if location B is dirty 
            print("moving to location B")
            if Environment.locationcondition['B']==1:
              print("location B is dirty.")
              #suck the dirt and mark it clean
              Environment.locationcondition['B']=0
              print("location B has been clean.")
              print("**********cleaning Envirinment**********")
            else:        
              print("**********B was cleaned**********")
              print("**********cleaning Envirinment**********")         
                
        elif vacumlocation==1:
            
            print("Vacum is randomly placed at location B.")
            #and if location B is dirty 
            if Environment.locationcondition['B']==1:
                print("location B is dirty.")
                #suck the dirt and mark it clean
                Environment.locationcondition['B']=0
                print("location B has been clean.")
                print("movingto location A")
                
            else:
                print("location B was cleaned")
                print("moving to location A")
            #and if location A is dirty 
            if Environment.locationcondition['A']==1:
                print("location A is dirty.")
                #suck the dirt and mark it clean
                Environment.locationcondition['A']=0
                print("location A has been clean.")
                print("**********cleaning Envirinment**********")
            else:
              print("location A was cleaned")
              print("**********cleaning Envirinment**********")
       

        else:
                print("**********cleaning Envirinment**********")

# %%
for i in range(1,5):
  print(f"=====Test{i}======")
  env1=Environment()
  ag1=Sreflexagent(env1)
# Out:
# =====Test1======
# Random Environment:
# {'A': 0, 'B': 1}
# Vacum is randomly placed at location A.
# location A was cleaned
# moving to location B
# moving to location B
# location B is dirty.
# location B has been clean.
# **********cleaning Envirinment**********
# =====Test2======
# Random Environment:
# {'A': 1, 'B': 1}
# Vacum is randomly placed at location B.
# location B is dirty.
# location B has been clean.
# movingto location A
# location A is dirty.
# location A has been clean.
# **********cleaning Envirinment**********
# =====Test3======
# Random Environment:
# {'A': 1, 'B': 0}
# Vacum is randomly placed at location B.
# location B was cleaned
# moving to location A
# location A is dirty.
# location A has been clean.
# **********cleaning Envirinment**********
# =====Test4======
# Random Environment:
# {'A': 0, 'B': 0}
# Vacum is randomly placed at location B.
# location B was cleaned
# moving to location A
# location A was cleaned
# moving to location A
